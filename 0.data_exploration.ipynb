# %%
# !python -m pip install plotnine

# %%
# !python -m pip install matplotlib-venn

# %%
import requests
import json
from pandas import json_normalize
import pandas as pd
import numpy as np
import re
from difflib import SequenceMatcher
import string
import itertools
from collections import Counter
from plotnine import ggplot, aes, geom_line, geom_point, geom_col, geom_bar, geom_density, geom_histogram, geom_hline, geom_vline, geom_text, theme, theme_minimal, theme_classic, labs, coord_flip, scale_fill_brewer, scale_color_manual, scale_x_discrete, scale_x_continuous, scale_y_continuous, position_stack, element_blank
from matplotlib_venn import venn2 
from matplotlib import pyplot as plt
import ast

# %%
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')
pd.reset_option('max_colwidth')

# %%
data = pd.read_csv('songs_lyrics.csv')

# %%
data.shape
# Out:
# (27114, 8)

# %%
data.groupby('status_API').size()
# Out:
# status_API
# 200    27114
# dtype: int64

# %%
res_api_df = data.groupby('res_API').size().reset_index(name="count")
res_api_df['perc'] = res_api_df['count']/res_api_df['count'].sum()
res_api_df['label'] = res_api_df.apply(lambda x: str(x['count']) + ' (' + str(round(x['perc']*100,1)) + '%)', axis=1)
# res_api_df.sort_values('count', inplace=True)
(
    ggplot(res_api_df)  
    + aes(x="res_API", y="count", label="label", fill="res_API") 
    + theme_minimal()
    + geom_col()  
    + geom_text(va="bottom", size=10)
    + labs(title='Results from Vagalume API',x='',y='')
    + theme(legend_position="none")
)
# Out:
# <ggplot: (273040252)>

# %%
# Let's take a look at the 'aprox' results
data_aprox = pd.read_csv('songs_lyrics_aprox.csv')
data_aprox['similarity'] = data_aprox.apply(lambda x: SequenceMatcher(a=re.sub("\(.*?\)|\[.*?\]","",x['name'].lower()).translate(str.maketrans('','',string.punctuation)), 
                                                                      b=x['name_API'].lower().translate(str.maketrans('','',string.punctuation))).ratio(), axis=1) 
data_aprox[['artist','name','name_API','similarity']]
# Out:
#              artist                      name  \
# 0        Gucci Mane                 Big Booty
# 1    Jennifer Lopez                     Booty
# 2      Jason Derulo                 Bubblegum
# 3      Jason Derulo                   Tip Toe
# 4      Jason Derulo                    Wiggle
# ..              ...                       ...
# 899  Jo Dee Messina           Where Were You?
# 900      Set It Off  Wolf In Sheep's Clothing
# 901         Beyoncé                  My Power
# 902       Kate Bush  Oh England, My Lionheart
# 903       Santigold           The Riot's Gone
#
#                                               name_API  similarity
# 0                  Big Booty (Ft. Megan Thee Stallion)    0.439024
# 1                            Booty (feat. Iggy Azalea)    0.370370
# 2                               Bubblegum (Feat. Tyga)    0.642857
# 3                       Tip Toe (Feat. French Montana)    0.411765
# 4                            Wiggle (Feat. Snoop Dogg)    0.428571
# ..                                                 ...         ...
# 899                                     Where Were You    1.000000
# 900   Wolf In Sheep's Clothing (Feat. William Beckett)    0.686567
# 901  My Power (With Tierra Whack, Moonchild Sanelly...    0.280702
# 902                            Oh England My Lionheart    1.000000
# 903                                     The Riots Gone    1.000000
#
# [904 rows x 4 columns]

# %%
# There are some songs that are just not taking featurings from another artists in the title. 
# It is always inside (), so let's remove it and compare it once again
# We will also remove any punctuations and keep all lower case
data_aprox['name_API_wo_feat'] = data_aprox['name_API'].apply(lambda x: re.sub("\(.*?\)|\[.*?\]","",x))
data_aprox['similarity_wo_feat'] = data_aprox.apply(lambda x: SequenceMatcher(a=re.sub("\(.*?\)|\[.*?\]","",x['name'].lower()).translate(str.maketrans('','',string.punctuation)), 
                                                                              b=x['name_API_wo_feat'].lower().translate(str.maketrans('','',string.punctuation))).ratio(), axis=1) 
data_aprox[['artist','name','name_API_wo_feat','similarity_wo_feat']]
# Out:
#              artist                      name           name_API_wo_feat  \
# 0        Gucci Mane                 Big Booty                 Big Booty
# 1    Jennifer Lopez                     Booty                     Booty
# 2      Jason Derulo                 Bubblegum                 Bubblegum
# 3      Jason Derulo                   Tip Toe                   Tip Toe
# 4      Jason Derulo                    Wiggle                    Wiggle
# ..              ...                       ...                        ...
# 899  Jo Dee Messina           Where Were You?             Where Were You
# 900      Set It Off  Wolf In Sheep's Clothing  Wolf In Sheep's Clothing
# 901         Beyoncé                  My Power                  My Power
# 902       Kate Bush  Oh England, My Lionheart    Oh England My Lionheart
# 903       Santigold           The Riot's Gone             The Riots Gone
#
#      similarity_wo_feat
# 0              0.947368
# 1              0.909091
# 2              0.947368
# 3              0.933333
# 4              0.923077
# ..                  ...
# 899            1.000000
# 900            0.978723
# 901            0.941176
# 902            1.000000
# 903            1.000000
#
# [904 rows x 4 columns]

# %%
similarity_stat = pd.DataFrame()
similarity_stat['stat'] = ['original','modified']
similarity_stat['value'] = [np.quantile(data_aprox['similarity'],0.05), np.quantile(data_aprox['similarity_wo_feat'],0.05)]
(
    ggplot(pd.concat([data_aprox.groupby('similarity_wo_feat').size().rename('n').reset_index().rename(columns={'similarity_wo_feat': 'similarity'}).assign(p_005='modified'),
                 data_aprox.groupby('similarity').size().rename('n').reset_index().assign(p_005='original')])) 
    + aes(x="similarity", color="p_005")  
    + theme_classic()
    + scale_y_continuous(expand=(0, 0, 0, 0))
    + scale_x_continuous(expand=(0, 0, 0, 0))
    + theme(legend_position = (0.5, 0.01),
            legend_title=element_blank())
    + geom_density() 
    + geom_vline(similarity_stat,aes(xintercept='value', colour='stat'), linetype='dashed', size=1)
    + labs(title="Distribution of similarity between name of the song from 'aprox' results",x='',y='')
)
# Out:
# <ggplot: (674558820)>

# %%
# 5% of the songs are under 0.75 of similarity. This is a high value and to be safe, we will remove this 5%, which represents 45 songs.
# We also need to remove the songs that were not found, as there won't be any information to work with. 
index_to_delete = data_aprox[data_aprox['similarity_wo_feat']<np.quantile(data_aprox['similarity_wo_feat'],0.05)]['song_index'].values
data = data[~data['song_index'].isin(index_to_delete)]
data = data[data['res_API'].isin(['aprox','exact'])]
data.shape
# Out:
# (21883, 8)

# %%
count_topics_stat = pd.DataFrame()
count_topics_stat['stat'] = ['mean','median']
count_topics_stat['value'] = [data.groupby('topic').size().describe()['mean'], data.groupby('topic').size().describe()['50%']]

(
    ggplot(data.groupby('topic').size().rename('n').reset_index())  
    + aes(x="n")  
    + theme_minimal()
    + geom_density() 
    + geom_vline(count_topics_stat,aes(xintercept='value', colour='stat'), linetype='dashed', size=1)
    + labs(title='Distribution of number of observation per Topic from SongFacts',x='',y='')
)
# Out:
# <ggplot: (672472614)>

# %%
topics_df = data.groupby('topic').size().reset_index(name="count")
topics_df['perc'] = topics_df['count']/topics_df['count'].sum()
topics_df['label'] = topics_df.apply(lambda x: str(x['count']) + ' (' + str(round(x['perc']*100,1)) + '%)', axis=1)
topics_df.sort_values('count', ascending=False, inplace=True)
(
    ggplot(topics_df.head(10))  
    + aes(x="topic", y="count", label="label", fill="topic")  
    + theme_minimal()
    + geom_col()  
    + geom_text(ha="left", size=10)
    + scale_x_discrete(limits=topics_df['topic'].tolist()[:10][::-1])
    + scale_y_continuous(expand=(0, 0, 0.2, 0))
    + labs(title='Top 10 Topics from SongFacts',x='',y='')
    + coord_flip()
    + theme(legend_position="none") 
)
# Out:
# <ggplot: (674436069)>

# %%
topics_df = data.groupby('topic').size().reset_index(name="count")
topics_df['perc'] = topics_df['count']/topics_df['count'].sum()
topics_df['label'] = topics_df.apply(lambda x: str(x['count']) + ' (' + str(round(x['perc']*100,1)) + '%)', axis=1)
topics_df.sort_values('count', ascending=True, inplace=True)
(
    ggplot(topics_df.head(10))  
    + aes(x="topic", y="count", label="label", fill="topic")  
    + theme_minimal()
    + geom_col()  
    + geom_text(ha="left", size=10)
    + scale_x_discrete(limits=topics_df['topic'].tolist()[:10][::-1])
    + scale_y_continuous(expand=(0, 0, 0.2, 0))
    + labs(title='Bottom 10 Topics from SongFacts',x='',y='')
    + coord_flip()
    + theme(legend_position="none") 
)
# Out:
# <ggplot: (672655706)>

# %%
artist_df = data.groupby('artist').size().reset_index(name="count")
artist_df['perc'] = artist_df['count']/artist_df['count'].sum()
artist_df['label'] = artist_df.apply(lambda x: str(x['count']) + ' (' + str(round(x['perc']*100,1)) + '%)', axis=1)
artist_df.sort_values('count', ascending=False, inplace=True)
(
    ggplot(artist_df.head(10))  
    + aes(x="artist", y="count", label="label", fill="artist")  
    + theme_minimal()
    + geom_col()  
    + geom_text(ha="left", size=10)
    + scale_x_discrete(limits=artist_df['artist'].tolist()[:10][::-1])
    + scale_y_continuous(expand=(0, 0, 0.2, 0))
    + labs(title='Top 10 Artists in Dataset',x='',y='')
    + coord_flip()
    + theme(legend_position="none") 
)
# Out:
# <ggplot: (674436084)>

# %%
# Are there songs with multiple labels?
topics_list_df = data.groupby(['artist','name'])['topic'].apply(list).reset_index(name='topics_list')
topics_list_df['n_list'] = topics_list_df['topics_list'].apply(lambda x: len(x))
topics_list_df[topics_list_df['n_list']>1].sort_values('n_list',ascending=False)
# Out:
#                 artist                     name  \
# 15684     Taylor Swift                 Epiphany
# 2234          Bon Jovi                Undivided
# 16642        The Kinks  Do You Remember Walter?
# 6000      Garth Brooks          Papa Loved Mama
# 6691     Harvey Danger           Flagpole Sitta
# ...                ...                      ...
# 6467         Green Day                    X-Kid
# 6476    Gregory Porter     Take Me To The Alley
# 6479   Gretchen Peters   Breakfast At Our House
# 6481   Gretchen Peters                  Imogene
# 18716        will.i.am      Reach for the Stars
#
#                                              topics_list  n_list
# 15684  [Songs about a grandparent, Songs about exhaus...       6
# 2234   [Songs about grieving, Songs about events in t...       5
# 16642  [Songs about childhood, Songs about friendship...       5
# 6000   [Songs about affairs, Songs about being away f...       5
# 6691   [Songs about being paranoid, Songs about being...       5
# ...                                                  ...     ...
# 6467   [Songs about suicide, Songs that are tributes ...       2
# 6476   [Songs about a mother or father, Songs about p...       2
# 6479   [Songs about marital problems or divorce, Song...       2
# 6481   [Songs about high school experiences, Songs ab...       2
# 18716           [Songs about science, Songs about space]       2
#
# [2798 rows x 4 columns]

# %%
# The song with most topics is Epiphany by Taylor Swift
topics_list_df.sort_values('n_list',ascending=False).iloc[0]['topics_list']
# Out:
# ['Songs about a grandparent',
#  'Songs about exhaustion',
#  'Songs about medical conditions',
#  'Songs about pressure or burdens',
#  'Songs about working',
#  'Songs about war']

# %%
more_than_one_topic_df = topics_list_df.groupby('n_list').size().reset_index(name="n")
more_than_one_topic_df['perc'] = more_than_one_topic_df['n']/more_than_one_topic_df['n'].sum()
more_than_one_topic_df['label'] = more_than_one_topic_df.apply(lambda x: str(x['n']) + '\n (' + str(round(x['perc']*100,1)) + '%)', axis=1)
(
    ggplot(more_than_one_topic_df)
    + aes(x="n_list", y="n", label="label")  
    + theme_minimal()
    + geom_col()  
    + geom_text(va="bottom",size=10)
    + scale_x_discrete(limits=more_than_one_topic_df['n_list'].tolist()[::1])
    + scale_y_continuous(expand=(0, 0, 0.2, 0))
    + labs(title='Songs with multiple labels',x='',y='')
    + theme(legend_position="none") 
)
# Out:
# <ggplot: (674466859)>

# %%
# Now we will take combinations of 2 to identify if there are any pair that is more common, and maybe belong together.
topics_list_df['topics_pair'] = topics_list_df.apply(lambda x: [list(i) for i in itertools.combinations(x['topics_list'], 2)], axis=1)
counter_list = Counter([str(i) for sublist in topics_list_df[topics_list_df['n_list']>1]['topics_pair'].values for i in sublist])
counter_list.most_common(10)
# Out:
# [("['Songs about a breakup', 'Songs about heartache']", 23),
#  ("['Songs about fatherhood or motherhood', 'Songs written for a son or daughter']",
#   23),
#  ("['Songs about dependency or addiction', 'Songs about drugs']", 21),
#  ("['Songs about alcohol', 'Songs about heartache']", 19),
#  ("['Songs about specific musicians', 'Songs that are tributes to friends who died']",
#   18),
#  ("['Songs about a mother or father', 'Songs that are tributes to friends who died']",
#   17),
#  ("['Songs about people who committed crimes', 'Songs about serial killers']",
#   14),
#  ("['Songs about events in the news', 'Songs about racism or discrimination']",
#   12),
#  ("['Songs about animals', 'Songs about dogs']", 12),
#  ("['Songs about an ex-girlfriend or ex-boyfriend', 'Songs about heartache']",
#   12)]

# %%
# Getting intersections
for topic in data['topic'].unique():
    topics_list_df[topic] = topics_list_df.apply(lambda x: 1 if topic in x['topics_list'] else 0, axis=1)

# %%
counter_array = counter_list.most_common(10000)
counter_df = pd.DataFrame()
index_array = []
both_perc_array = []
n_songs_array = []
largest_topic_array = []
smaller_topic_array = []
n_largest_array = []
n_smallest_array = []
for index in range(len(counter_array)):
    if len(set(ast.literal_eval(counter_list.most_common(10000)[index][0])))>1:
        combination_labels = ast.literal_eval(counter_list.most_common(10000)[index][0])
        combination_df = topics_list_df[(topics_list_df[combination_labels[0]]==1) | (topics_list_df[combination_labels[1]]==1)][combination_labels]
        combination_df['both'] = combination_df.apply(lambda x: 1 if x[combination_labels[0]]==1 and x[combination_labels[1]]==1 else 0, axis=1)
        index_array.append(index)
        both_perc_array.append(round(combination_df.sum()['both']/combination_df.shape[0]*100,2))
        n_songs_array.append(combination_df.sum()['both'])
        largest_topic_array.append(combination_df[combination_labels].sum().sort_values(ascending=False).index[0])
        smaller_topic_array.append(combination_df[combination_labels].sum().sort_values(ascending=True).index[0])
        n_largest_array.append(combination_df[combination_labels].sum().sort_values(ascending=False)[0])
        n_smallest_array.append(combination_df[combination_labels].sum().sort_values(ascending=True)[0])

counter_df['index'] = index_array
counter_df['both_perc'] = both_perc_array
counter_df['n_songs'] = n_songs_array
counter_df['largest_topic'] = largest_topic_array
counter_df['smaller_topic'] = smaller_topic_array
counter_df['n_largest'] = n_largest_array
counter_df['n_smallest'] = n_smallest_array

# %%
counter_df.sort_values(by=['both_perc'], ascending=False)
# Out:
#       index  both_perc  n_songs                            largest_topic  \
# 488     488      15.38        2                     Songs about bad luck
# 8         8      12.12       12                      Songs about animals
# 198     198       9.38        3          Songs about fictional musicians
# 1         1       9.24       23      Songs written for a son or daughter
# 6         6       7.29       14  Songs about people who committed crimes
# ...     ...        ...      ...                                      ...
# 1420   1421       0.10        1                    Songs about heartache
# 945     945       0.10        1                    Songs about heartache
# 1442   1443       0.10        1                    Songs about heartache
# 1291   1292       0.09        1                    Songs about heartache
# 1501   1503       0.09        1                    Songs about heartache
#
#                                 smaller_topic  n_largest  n_smallest
# 488                 Songs about superstitions          9           6
# 8                            Songs about dogs         90          21
# 198   Songs about buskers or street musicians         23          12
# 1        Songs about fatherhood or motherhood        216          56
# 6                  Songs about serial killers        185          21
# ...                                       ...        ...         ...
# 1420            Songs about dealing with fame        769         249
# 945            Songs about specific musicians        769         208
# 1442                 Songs about getting away        769         185
# 1291           Songs about a mother or father        769         385
# 1501                          Songs about war        769         295
#
# [2142 rows x 7 columns]

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('max_colwidth', None)

smallertopic_count_df = counter_df.groupby('smaller_topic').count().reset_index().sort_values('index', ascending=False)[['smaller_topic','largest_topic']]
largertopic_count_df = counter_df.groupby('largest_topic').count().reset_index().sort_values('index', ascending=False)[['largest_topic','smaller_topic']]
large_small_df = largertopic_count_df.merge(smallertopic_count_df, left_on='largest_topic', right_on='smaller_topic', how='left').drop('smaller_topic_y',axis=1)
large_small_df['which'] = large_small_df.apply(lambda x: 'large' if x['smaller_topic_x']>x['largest_topic_y'] 
                                               else 'large' if pd.isna(x['largest_topic_y']) 
                                               else 'small', axis=1)
large_small_df
# Out:
#                                          largest_topic_x  smaller_topic_x  \
# 0                                  Songs about heartache               69
# 1                        Songs that are autobiographical               64
# 2                         Songs about a mother or father               56
# 3                    Songs about loneliness or isolation               56
# 4                               Songs written for a girl               52
# 5                         Songs about events in the news               50
# 6                                  Songs about a breakup               49
# 7                   Songs about spirituality or religion               49
# 8           Songs about an ex-girlfriend or ex-boyfriend               47
# 9                                     Songs about places               46
# 10                         Songs about dealing with fame               42
# 11                                     Songs about death               42
# 12           Songs that are tributes to friends who died               41
# 13                       Songs with political statements               40
# 14                                       Songs about sex               39
# 15                                     Songs about drugs               39
# 16                Songs about being away from loved ones               35
# 17                             Songs about getting older               32
# 18                         Songs about historical events               32
# 19                                  Songs about cheating               31
# 20                                Songs about depression               31
# 21                                Songs about friendship               30
# 22                                       Songs about war               30
# 23                              Songs about getting away               29
# 24               Songs about marital problems or divorce               29
# 25                        Songs about medical conditions               28
# 26                                    Songs about change               28
# 27                                     Songs about music               27
# 28                              Songs about perseverance               27
# 29                  Songs about being young and confused               26
# 30                   Songs about being there for someone               25
# 31                             Songs about individuality               24
# 32                   Songs about clubbing or a night out               21
# 33                     Songs about confidence or courage               21
# 34                                   Songs about alcohol               21
# 35                                 Songs about childhood               21
# 36               Songs about people who committed crimes               21
# 37                   Songs written for a son or daughter               21
# 38                         Songs about political figures               20
# 39                              Songs about finding love               20
# 40             Songs about looking back on fond memories               20
# 41                        Songs about specific musicians               20
# 42                         Songs about desire or longing               20
# 43                                 Songs about traveling               20
# 44                         Songs about joy and happiness               20
# 45                                Songs about being free               20
# 46                   Songs about computers or technology               19
# 47                  Songs about racism or discrimination               19
# 48                        Songs about the music industry               18
# 49                   Songs about dependency or addiction               17
# 50                   Songs about leaving the past behind               17
# 51                   Songs about unhealthy relationships               17
# 52                           Songs about vanity or greed               14
# 53                           Songs about unrequited love               14
# 54                                    Songs about regret               12
# 55                       Songs about being misunderstood               12
# 56                                   Songs about choices               12
# 57                                   Songs about suicide               12
# 58                                   Songs about affairs               12
# 59                Songs about the dangers of materialism               12
# 60                           Songs about the environment               12
# 61                                     Songs about women               12
# 62                   Songs about high school experiences               11
# 63                                   Songs about animals               11
# 64                          Songs about optimism or hope               11
# 65                                 Songs about the media               11
# 66                      Songs about living in the moment               11
# 67                                  Songs about betrayal               11
# 68                                End-of-the-world songs               11
# 69     Songs about magic, witchcraft, UFOs or the occult               10
# 70                                   Songs about dancing               10
# 71                                     Songs about unity               10
# 72            Songs about people with financial problems               10
# 73                                    Songs about nature                9
# 74                                   Songs about working                9
# 75                           Songs about fear or anxiety                8
# 76                    Songs about pride in your heritage                8
# 77                                  Songs about insanity                8
# 78                             Songs about band dynamics                8
# 79                     Songs about commitment or respect                8
# 80                       Songs about laziness or boredom                7
# 81   Songs about trying to write a song or make an album                7
# 82                                  Songs about jealousy                7
# 83                              Songs about social media                7
# 84                             Songs about a fresh start                7
# 85                             Songs about a grandparent                7
# 86             Songs about reconciliation or forgiveness                6
# 87                        Songs about female empowerment                6
# 88                       Songs about pressure or burdens                6
# 89                            Songs about being paranoid                6
# 90                                  Songs about grieving                6
# 91                          Songs about rock star excess                6
# 92                      Songs about peace or tranquility                5
# 93                                      Songs about fans                5
# 94                                        Kiss-off songs                5
# 95                                   Songs about crushes                5
# 96                    Songs about living in a small town                4
# 97                               Songs about prostitutes                4
# 98                       Songs about strippers or models                4
# 99                   Songs about being crazy for someone                3
# 100                 Songs about messiahs or cult leaders                3
# 101             Songs about liars or people who are fake                3
# 102                                Songs about rejection                3
# 103                                     Songs about dogs                3
# 104                  Songs about encounters with the law                3
# 105                                    Songs about money                3
# 106                                  Songs about fashion                3
# 107                         Songs about feeling helpless                3
# 108                              Songs written for a guy                3
# 109                              Songs about rockin' out                3
# 110                                Songs about pregnancy                3
# 111                          Songs about anger or hatred                3
# 112               Songs about inner beauty or body image                2
# 113              Songs about homelessness or desperation                2
# 114              Songs about encouragement or acceptance                2
# 115                                    Songs about sleep                2
# 116                                Songs about a stalker                2
# 117                              Songs about photographs                2
# 118                       Songs about robots or androids                2
# 119                              Songs about Los Angeles                2
# 120                           Songs about radio stations                2
# 121                             Songs about consequences                2
# 122        Songs about getting out of a bad relationship                2
# 123                         Songs about Native Americans                2
# 124                       Songs about prescription drugs                2
# 125                            Songs for Valentine's Day                2
# 126              Songs about trying to give something up                1
# 127                         Songs about trying to fit in                1
# 128                                    Pessimistic songs                1
# 129                                   Songs about trends                1
# 130                                   Songs about a date                1
# 131                                    Songs about boats                1
# 132                 Songs about fatherhood or motherhood                1
# 133                               Songs about temptation                1
# 134                 Songs about being taken advantage of                1
# 135                  Songs about inventors or scientists                1
# 136                                        Goodbye songs                1
# 137               Songs about gratitude or giving thanks                1
# 138                           Songs about love triangles                1
# 139                        Songs about celebrity culture                1
# 140                             Songs about masturbation                1
# 141                    Songs about misfits and underdogs                1
# 142                                  Songs about battles                1
# 143                       Songs about chaos or confusion                1
# 144                      Songs about fictional musicians                1
# 145                                Songs about rebellion                1
# 146                                 Songs about groupies                1
# 147                                  Songs about revenge                1
# 148                                  Songs about science                1
# 149                           Songs about serial killers                1
# 150                                  Songs about slavery                1
# 151                                    Songs about space                1
# 152                               Songs about television                1
# 153                                 Songs about bad luck                1
#
#      largest_topic_y  which
# 0                NaN  large
# 1               11.0  large
# 2                1.0  large
# 3               11.0  large
# 4                1.0  large
# 5                7.0  large
# 6                4.0  large
# 7                1.0  large
# 8                3.0  large
# 9                3.0  large
# 10              11.0  large
# 11               5.0  large
# 12               5.0  large
# 13               2.0  large
# 14               2.0  large
# 15               4.0  large
# 16              10.0  large
# 17              12.0  large
# 18               7.0  large
# 19               9.0  large
# 20              10.0  large
# 21              19.0  large
# 22               8.0  large
# 23              18.0  large
# 24              13.0  large
# 25              16.0  large
# 26              13.0  large
# 27               9.0  large
# 28               8.0  large
# 29              16.0  large
# 30              11.0  large
# 31               6.0  large
# 32               9.0  large
# 33               6.0  large
# 34              13.0  large
# 35              17.0  large
# 36              12.0  large
# 37               9.0  large
# 38               7.0  large
# 39               6.0  large
# 40              22.0  small
# 41              10.0  large
# 42              13.0  large
# 43              11.0  large
# 44               4.0  large
# 45              17.0  large
# 46               9.0  large
# 47              14.0  large
# 48              16.0  large
# 49              12.0  large
# 50              22.0  small
# 51              15.0  large
# 52              14.0  small
# 53               8.0  large
# 54              19.0  small
# 55              17.0  small
# 56              19.0  small
# 57              14.0  small
# 58              17.0  small
# 59              11.0  large
# 60              11.0  large
# 61              13.0  small
# 62              17.0  small
# 63              12.0  small
# 64              22.0  small
# 65              12.0  small
# 66              13.0  small
# 67              11.0  small
# 68              14.0  small
# 69               6.0  large
# 70              13.0  small
# 71              14.0  small
# 72              13.0  small
# 73              25.0  small
# 74              17.0  small
# 75              16.0  small
# 76              15.0  small
# 77              13.0  small
# 78              10.0  small
# 79               8.0  small
# 80              13.0  small
# 81              10.0  small
# 82               9.0  small
# 83              17.0  small
# 84              16.0  small
# 85              19.0  small
# 86              16.0  small
# 87              10.0  small
# 88              20.0  small
# 89              17.0  small
# 90              21.0  small
# 91               6.0  small
# 92              14.0  small
# 93               6.0  small
# 94              10.0  small
# 95               8.0  small
# 96              15.0  small
# 97               6.0  small
# 98               5.0  small
# 99               7.0  small
# 100             10.0  small
# 101             19.0  small
# 102             13.0  small
# 103              8.0  small
# 104             15.0  small
# 105              6.0  small
# 106             12.0  small
# 107             12.0  small
# 108             11.0  small
# 109             12.0  small
# 110             11.0  small
# 111             19.0  small
# 112              8.0  small
# 113              9.0  small
# 114             12.0  small
# 115             18.0  small
# 116              7.0  small
# 117             22.0  small
# 118              6.0  small
# 119             16.0  small
# 120              1.0  large
# 121             13.0  small
# 122             18.0  small
# 123              8.0  small
# 124             15.0  small
# 125              5.0  small
# 126             18.0  small
# 127             13.0  small
# 128              5.0  small
# 129              9.0  small
# 130              5.0  small
# 131             10.0  small
# 132             13.0  small
# 133             13.0  small
# 134             11.0  small
# 135              8.0  small
# 136             16.0  small
# 137             15.0  small
# 138             11.0  small
# 139              8.0  small
# 140              2.0  small
# 141              9.0  small
# 142              6.0  small
# 143              8.0  small
# 144             11.0  small
# 145              8.0  small
# 146              2.0  small
# 147             12.0  small
# 148              8.0  small
# 149              4.0  small
# 150              6.0  small
# 151             10.0  small
# 152              2.0  small
# 153              2.0  small

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('max_colwidth', None)

labels_to_remove = set(counter_df['smaller_topic']) - set(large_small_df[large_small_df['which']=='large']['largest_topic_x'])
labels_to_remove_df = counter_df[(counter_df['smaller_topic'].isin(labels_to_remove)) & (~counter_df['largest_topic'].isin(labels_to_remove))]\
    .sort_values(['smaller_topic','both_perc'], ascending=[True, False])\
    .groupby('smaller_topic').agg({'n_smallest': 'max',
                                   'largest_topic': lambda x: list(x),
                                   'both_perc': lambda x: list(x)
                                   })\
    .reset_index()\
    .sort_values('n_smallest', ascending=False)

labels_to_remove_df['n_larger_topics'] = labels_to_remove_df['largest_topic'].apply(lambda x: len(x))
labels_to_remove_df
# Out:
#                                            smaller_topic  n_smallest  \

# 3                                                                                                                                                                                                                                                                                                                                                                                                                               [Songs about an ex-girlfriend or ex-boyfriend, Songs about a breakup, Songs about cheating, Songs about getting away, Songs about joy and happiness, Songs about heartache, Songs about being away from loved ones, Songs that are autobiographical]
# 73                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [Songs about sex, Songs about desire or longing]
# 130                                                                                                                                                                                                                                                                                                                           [Songs about computers or technology, Songs about depression, Songs about events in the news, Songs about being young and confused, Songs about the environment, Songs about the music industry, Songs about a breakup, Songs about people who committed crimes, Songs about joy and happiness, Songs about change, Songs about confidence or courage]
# ...
# 68                                                                                                               [0.58, 0.36, 0.34]
# 115                                                                                       [0.57, 0.47, 0.29, 0.29, 0.25, 0.24, 0.2]
# 136                                                              [1.06, 0.94, 0.79, 0.44, 0.42, 0.36, 0.36, 0.32, 0.29, 0.19, 0.19]
# 103                                             [0.94, 0.69, 0.55, 0.54, 0.42, 0.41, 0.39, 0.34, 0.29, 0.26, 0.25, 0.25, 0.2, 0.18]
# 122                                                                                  [1.55, 0.6, 0.59, 0.45, 0.42, 0.37, 0.3, 0.28]
# 111                                                                                                        [1.18, 0.57, 0.51, 0.25]
# 10                                                                   [2.74, 2.15, 0.9, 0.84, 0.72, 0.7, 0.58, 0.44, 0.4, 0.3, 0.25]
# 107                                                                  [1.44, 1.03, 0.6, 0.51, 0.41, 0.4, 0.4, 0.35, 0.3, 0.27, 0.26]
# 106                                                                           [2.42, 1.21, 0.85, 0.43, 0.3, 0.28, 0.27, 0.24, 0.18]
# 11                                                                                               [3.51, 1.69, 0.6, 0.58, 0.3, 0.18]
# 154                                                                                                               [1.3, 0.39, 0.34]
# 129                                                                                                   [0.87, 0.48, 0.43, 0.35, 0.3]
# 145                                                                           [1.21, 0.59, 0.56, 0.46, 0.45, 0.45, 0.4, 0.36, 0.36]
# 17                                                           [0.69, 0.45, 0.44, 0.37, 0.33, 0.3, 0.26, 0.25, 0.23, 0.2, 0.19, 0.18]
# 45                                                                                             [1.84, 0.81, 0.43, 0.43, 0.43, 0.29]
# 134                                                                                                  [1.08, 0.46, 0.45, 0.43, 0.35]
# 48                                                                            [0.61, 0.59, 0.56, 0.48, 0.36, 0.28, 0.26, 0.23, 0.2]
# 141                                                                                                               [0.52, 0.35, 0.3]
# 0                                                                                                                [0.38, 0.36, 0.19]
# 91                                                                                             [0.91, 0.61, 0.47, 0.37, 0.36, 0.33]
# 64                                                                                              [0.53, 0.37, 0.31, 0.3, 0.29, 0.13]
# 52                                                                                              [0.53, 0.53, 0.43, 0.35, 0.24, 0.2]
# 2                                                             [0.95, 0.47, 0.43, 0.43, 0.36, 0.36, 0.31, 0.3, 0.3, 0.24, 0.2, 0.13]
# 135                                                                                                                    [0.47, 0.24]
# 70                                                                                        [0.73, 0.44, 0.36, 0.33, 0.31, 0.2, 0.19]
# 117                                                                                                  [5.42, 0.61, 0.41, 0.31, 0.28]
# 16                                                                                                                [0.44, 0.4, 0.35]
# 37                                                                                        [0.66, 0.44, 0.44, 0.31, 0.24, 0.2, 0.19]
# 123                                                                                                  [0.88, 0.61, 0.35, 0.29, 0.13]
# 143                                                                                                              [0.39, 0.31, 0.24]
# 124                                                                                                        [0.67, 0.58, 0.54, 0.37]
# 93                                                                                                     [1.0, 0.72, 0.6, 0.56, 0.54]
# 92                                                                                                                           [0.31]
# 89                                                                                                   [1.44, 0.35, 0.24, 0.19, 0.13]
# 157                                                                    [1.19, 0.76, 0.38, 0.33, 0.31, 0.28, 0.26, 0.24, 0.19, 0.13]
# 36                                                                                             [0.62, 0.47, 0.39, 0.37, 0.37, 0.13]
# 43                                                                                                          [3.4, 1.53, 0.94, 0.35]
# 8                                                                                                [2.6, 1.07, 0.6, 0.49, 0.42, 0.41]
# 21                                                                                       [1.43, 0.94, 0.88, 0.39, 0.31, 0.31, 0.26]
# 96                                                                                                   [0.95, 0.64, 0.36, 0.31, 0.31]
# 66                                                                                             [0.79, 0.74, 0.62, 0.55, 0.43, 0.37]
# 75                                                                                                   [2.78, 0.51, 0.38, 0.24, 0.13]
# 57                                                                                              [1.33, 0.51, 0.51, 0.32, 0.31, 0.2]
# 126                                                                                                                    [7.29, 0.31]
# 112                                                                                             [0.49, 0.48, 0.44, 0.24, 0.2, 0.13]
# 53                                                                                                   [0.63, 0.55, 0.46, 0.28, 0.24]
# 82                                                                                  [2.49, 0.6, 0.59, 0.49, 0.45, 0.45, 0.44, 0.25]
# 127                                                                                                  [3.11, 0.63, 0.56, 0.45, 0.13]
# 105                                                                                              [1.5, 0.61, 0.6, 0.51, 0.32, 0.27]
# 95                                                                                                                     [0.57, 0.44]
# 6                                                                                                           [1.34, 0.5, 0.49, 0.32]
# 39                                                                                       [0.56, 0.51, 0.49, 0.45, 0.32, 0.31, 0.13]
# 151                                                                                       [2.95, 0.66, 0.43, 0.34, 0.3, 0.26, 0.25]
# 15                                                                                                                           [0.79]
# 142                                                                                                   [0.8, 0.56, 0.26, 0.25, 0.13]
# 120                                                                                                  [2.11, 0.93, 0.81, 0.34, 0.19]
# 67                                                                                                            [0.46, 0.4, 0.3, 0.2]
# 125                                                                                                         [1.1, 0.42, 0.27, 0.13]
# 74                                                                                                    [1.56, 1.05, 0.5, 0.31, 0.27]
# 60                                                                                                               [0.57, 0.27, 0.25]
# 5                                                                                                                       [0.38, 0.3]
# 24                                                                                                         [0.78, 0.45, 0.41, 0.29]
# 31                                                                                                                       [1.4, 1.3]
# 27                                                                                                     [0.52, 0.46, 0.4, 0.27, 0.2]
# 137                                                                                                        [1.59, 1.41, 0.62, 0.13]
# 4                                                                                                                [0.57, 0.46, 0.32]
# 49                                                                                                          [1.59, 0.62, 0.6, 0.52]
# 140                                                                                                                          [1.32]
# 94                                                                                                     [2.14, 1.9, 0.38, 0.32, 0.3]
# 81                                                                                                     [0.58, 0.53, 0.5, 0.33, 0.2]
# 54                                                                                                    [2.33, 0.58, 0.53, 0.5, 0.45]
# 22                                                                                                    [1.33, 0.97, 0.32, 0.25, 0.2]
# 144                                                                                             [1.0, 0.68, 0.44, 0.41, 0.39, 0.21]
# 40                                                                                                                     [0.46, 0.41]
# 13                                                                                                     [3.4, 0.55, 0.4, 0.21, 0.19]
# 99                                                                                                    [2.74, 1.64, 1.43, 0.3, 0.25]
# 121                                                                                                   [0.75, 0.5, 0.43, 0.33, 0.19]
# 104                                                                                                        [1.18, 0.51, 0.47, 0.44]
# 44                                                                                                               [2.22, 0.64, 0.41]
# 78                                                                                                          [0.7, 0.46, 0.32, 0.19]
# 9                                                                                                           [1.4, 0.54, 0.47, 0.39]
# 28                                                                                                                     [1.67, 0.25]
# 41                                                                                                               [0.33, 0.21, 0.21]
# 58                                                                                                                           [3.45]
# 156                                                                                                                [0.7, 0.6, 0.41]
# 30                                                                                                         [0.83, 0.47, 0.45, 0.32]
# 12                                                                                                                     [0.58, 0.39]
# 7                                                                                                                       [2.44, 0.4]
# 42                                                                                                                     [0.53, 0.33]
# 138                                                                                                              [0.53, 0.49, 0.42]
# 155                                                                                                                     [0.5, 0.31]
#
#      n_larger_topics
# 114               19
# 85                21
# 90                21
# 51                12
# 88                10
# 47                 7
# 133               13
# 38                10
# 23                16
# 102               13
# 29                 6
# 113               15
# 46                16
# 148               13
# 152               10
# 1                 13
# 65                 8
# 109               12
# 158                8
# 147               10
# 59                 6
# 19                14
# 100               18
# 80                 9
# 33                 6
# 97                 6
# 26                10
# 150               12
# 110                6
# 153               10
# 63                13
# 139               10
# 119                8
# 84                 9
# 34                13
# 98                20
# 72                17
# 101               10
# 83                 7
# 118                5
# 86                16
# 76                12
# 35                11
# 14                15
# 77                 4
# 56                 9
# 132                3
# 108               10
# 79                 4
# 50                 6
# 3                  8
# 73                 2
# 130               11
# 62                10
# 18                12
# 131                9
# 71                11
# 128               11
# 87                 9
# 69                14
# 25                 9
# 32                 6
# 116                5
# 20                 5
# 55                11
# 61                 9
# 146               11
# 149                4
# 68                 3
# 115                7
# 136               11
# 103               14
# 122                8
# 111                4
# 10                11
# 107               11
# 106                9
# 11                 6
# 154                3
# 129                5
# 145                9
# 17                12
# 45                 6
# 134                5
# 48                 9
# 141                3
# 0                  3
# 91                 6
# 64                 6
# 52                 6
# 2                 12
# 135                2
# 70                 7
# 117                5
# 16                 3
# 37                 7
# 123                5
# 143                3
# 124                4
# 93                 5
# 92                 1
# 89                 5
# 157               10
# 36                 6
# 43                 4
# 8                  6
# 21                 7
# 96                 5
# 66                 6
# 75                 5
# 57                 6
# 126                2
# 112                6
# 53                 5
# 82                 8
# 127                5
# 105                6
# 95                 2
# 6                  4
# 39                 7
# 151                7
# 15                 1
# 142                5
# 120                5
# 67                 4
# 125                4
# 74                 5
# 60                 3
# 5                  2
# 24                 4
# 31                 2
# 27                 5
# 137                4
# 4                  3
# 49                 4
# 140                1
# 94                 5
# 81                 5
# 54                 5
# 22                 5
# 144                6
# 40                 2
# 13                 5
# 99                 5
# 121                5
# 104                4
# 44                 3
# 78                 4
# 9                  4
# 28                 2
# 41                 3
# 58                 1
# 156                3
# 30                 4
# 12                 2
# 7                  2
# 42                 2
# 138                3
# 155                2

# %%
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')
pd.reset_option('max_colwidth')

# %%
data.groupby(["name","artist"]).count().reset_index().shape
# Out:
# (18719, 8)

# %%
data[~data['topic'].isin(labels_to_remove)].groupby(["name","artist"]).count().reset_index().shape
# Out:
# (12948, 8)

# %%
data_full = data.groupby('topic').size().rename('n').reset_index()
data_full['source'] = 'all topics'
data_largeonly = data[~data['topic'].isin(labels_to_remove)].groupby('topic').size().rename('n').reset_index()
data_largeonly['source'] = 'subtopics removed'

(
    ggplot(pd.concat([data_full, data_largeonly]))  
    + aes(x="n", color="source", fill="source")  
    + theme_classic()
    + geom_density(alpha=0.3) 
    + scale_y_continuous(expand=(0, 0, 0, 0))
    + scale_x_continuous(expand=(0, 0, 0, 0))
    + labs(title='Distribution of number of observations per Topic',x='',y='')
    + theme(legend_position = (0.5, 0.01),
            legend_title=element_blank())
)
# Out:
# <ggplot: (696810058)>

# %%
combination_labels = ast.literal_eval(counter_list.most_common(10000)[8][0])
combination_df = topics_list_df[(topics_list_df[combination_labels[0]]==1) | (topics_list_df[combination_labels[1]]==1)][combination_labels]
combination_df['both'] = combination_df.apply(lambda x: 1 if x[combination_labels[0]]==1 and x[combination_labels[1]]==1 else 0, axis=1)
venn2(subsets = combination_df.sum().values, set_labels = combination_labels)
plt.show()

# %%
data = data.merge(topics_list_df, on=['artist','name'], how='left')

# %%
data['has_more_than_one_topic'] = data['n_list'].apply(lambda x: '1' if x>1 else '0')
perc_more_topic_df = data.groupby(['topic','has_more_than_one_topic']).size().reset_index(name="count")
perc_more_topic_df['perc'] = perc_more_topic_df['count']/perc_more_topic_df.groupby('topic')['count'].transform('sum')
perc_more_topic_df['label'] = perc_more_topic_df.apply(lambda x: round(x['perc'],2), axis=1)
perc_more_topic_df.sort_values(['has_more_than_one_topic','perc'], ascending=False, inplace=True)
(
    ggplot(perc_more_topic_df[perc_more_topic_df['topic'].isin(perc_more_topic_df.head(50).topic)])  
    + aes(x="topic", y="perc", label="count", fill="has_more_than_one_topic") 
    + theme_minimal()
    + geom_col(position = "fill")  
    + geom_text(size=8, position = position_stack(vjust = .5))
    + scale_x_discrete(limits=perc_more_topic_df['topic'].tolist()[:50][::-1])
    + coord_flip()
    + labs(title='Percentage of multi-label by Topic',x='',y='')
    + theme(figure_size=(6.4, 8.8))
)
# Out:
# <ggplot: (674517038)>

# %%
data['has_more_than_one_topic'] = data['n_list'].apply(lambda x: '1' if x>1 else '0')
perc_more_topic_df = data.groupby(['topic','has_more_than_one_topic']).size().reset_index(name="count")
perc_more_topic_df['perc'] = perc_more_topic_df['count']/perc_more_topic_df.groupby('topic')['count'].transform('sum')
perc_more_topic_df['label'] = perc_more_topic_df.apply(lambda x: round(x['perc'],2), axis=1)
perc_more_topic_df.sort_values(['has_more_than_one_topic','count'], ascending=False, inplace=True)
(
    ggplot(perc_more_topic_df[perc_more_topic_df['topic'].isin(perc_more_topic_df.head(50).topic)])  
    + aes(x="topic", y="perc", label="count", fill="has_more_than_one_topic") 
    + theme_minimal()
    + geom_col(position = "fill")  
    + geom_text(size=8, position = position_stack(vjust = .5))
    + scale_x_discrete(limits=perc_more_topic_df['topic'].tolist()[:50][::-1])
    + coord_flip()
    + labs(title='Percentage of multi-label by Topic',x='',y='')
    + theme(figure_size=(6.4, 8.8))
)
# Out:
# <ggplot: (672405144)>

# %%
perc_more_topic_df[(perc_more_topic_df['has_more_than_one_topic']=='0') & (perc_more_topic_df['perc']>0.7)]
# Out:
#                                             topic has_more_than_one_topic  \
# 202                         Songs about heartache                       0
# 333                               Songs about sex                       0
# 424                      Songs written for a girl                       0
# 347          Songs about spirituality or religion                       0
# 54   Songs about an ex-girlfriend or ex-boyfriend                       0
# ..                                            ...                     ...
# 32               Songs about a circus or carnival                       0
# 176                          Songs about fighting                       0
# 104                        Songs about censorship                       0
# 14                                Songs about DJs                       0
# 413  Songs of or about the Northern Soul movement                       0
#
#      count      perc  label
# 202    604  0.785436   0.79
# 333    434  0.887526   0.89
# 424    428  0.835938   0.84
# 347    413  0.867647   0.87
# 54     374  0.790698   0.79
# ..     ...       ...    ...
# 32      14  0.736842   0.74
# 176     12  0.705882   0.71
# 104      8  0.727273   0.73
# 14       5  0.714286   0.71
# 413      5  1.000000   1.00
#
# [94 rows x 5 columns]

# %%
topics = data.groupby('topic').size().reset_index(name='n').sort_values('n',ascending=False).topic.values
total_n = data.shape[0]
count_n = 0
count_topics_n = pd.DataFrame()
for i in range(len(topics)):
    n_topic = data[data['topic']==topics[i]].shape[0]
    count_n += n_topic
    share_topic = count_n/total_n
    count_topics_n=pd.concat([count_topics_n,pd.DataFrame({'n': [i+1],
                 'share': [share_topic]
                })])

# %%
(
    ggplot(count_topics_n)
    + aes(x="n", y="share")  
    + theme_minimal()
    + geom_line() 
    + geom_point(count_topics_n[count_topics_n['n'].isin([54,108,150])])
    + geom_text(count_topics_n[count_topics_n['n'].isin([54,108,150])], aes(label='np.round(share,2)'), va="bottom",ha="right", size=9)
    + labs(title='Percentage of observations by number of labels',x='',y='')
)
# Out:
# <ggplot: (674512059)>

# %%
# Now let's try to find a threshold to remove any topic that by itself only has this amount of songs
count_topics_remove = pd.DataFrame()
for i in range(0,100):
    topics_to_remove = perc_more_topic_df[(perc_more_topic_df['has_more_than_one_topic']=='0') & (perc_more_topic_df['count']<i)].topic.values
    share_remaining = (data.shape[0] - data[data['topic'].isin(topics_to_remove)].shape[0])/data.shape[0]
    count_topics_remove=pd.concat([count_topics_remove,pd.DataFrame({'n': [i],
                 'share': [share_remaining]
                })])

# %%
(
    ggplot(count_topics_remove)
    + aes(x="n", y="share")  
    + theme_minimal()
    + geom_line() 
    + geom_point(count_topics_remove[count_topics_remove['n'].isin([5,10,15])])
    + geom_text(count_topics_remove[count_topics_remove['n'].isin([5,10,15])], aes(label='np.round(share,2)'), va="bottom",ha="right", size=9)
    + labs(title='Percentage of observations by number of labels',x='',y='')
)
# Out:
# <ggplot: (674517566)>

# %%
data.to_csv('songs_lyrics_post_eda.csv')
data[~data['topic'].isin(labels_to_remove)].to_csv('songs_lyrics_training.csv')
